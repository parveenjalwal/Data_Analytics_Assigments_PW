# %%
**EDA - 1**


1 What is the range of selling prices in the dataset?
-The range of selling prices in the dataset is from ₹5,000 to ₹7,60,000, making the total range ₹7,55,000.



2 What is the median selling price for bikes in the dataset?
-The median selling price for bikes in the dataset is ₹45,000.


3 What is the most common seller type?
-The most common seller type in the dataset is "Individual".


4 How many bikes have driven more than 50,000 kilometers?
-There are 170 bikes in the dataset that have been driven more than 50,000 kilometers.


5 What is the average km_driven value for each ownership type?
-The average kilometers driven for each ownership type are:

1st owner: 32,817 km
2nd owner: 39,289 km
3rd owner: 33,292 km
4th owner and above: 311,500 km (likely due to outliers)


6 What proportion of bikes are from the year 2015 or older?
-Approximately 56.64% of the bikes in the dataset are from the year 2015 or older. Let me know if you need any more insights!


7 What is the trend of missing values across the dataset?
-The only column with missing values in the dataset is "ex_showroom_price", which has 435 missing values, accounting for 41% of the dataset.

All other columns have no missing values. Let me know if you need help handling these missing values.


8 What is the highest ex_showroom_price recorded, and for which bike?
-The highest ex-showroom price recorded is ₹12,78,000, and it belongs to the Harley-Davidson Street Bob.


9 What is the total number of bikes listed by each seller type?
-The total number of bikes listed by each seller type:

- **Individual:** 1,055 bikes
- **Dealer:** 6 bikes

The majority of listings come from individual sellers.


10 What is the relationship between selling_price and km_driven for first-owner bikes?
-The scatter plot shows the relationship between **selling price** and **kilometers driven** for first-owner bikes. Generally, as **km driven increases, the selling price tends to decrease**, indicating depreciation due to usage. However, there may be some outliers where high-priced bikes have higher mileage.


11 Identify and remove outliers in the km_driven column using the IQR method?
-A total of 39 outliers were identified and removed from the km_driven column using the IQR method.


12 Perform a bivariate analysis to visualize the relationship between year and selling_price.
-The scatter plot shows the relationship between **manufacturing year** and **selling price**. Generally, newer bikes tend to have higher selling prices, while older models depreciate in value. However, some exceptions might exist due to premium or rare models retaining their value.


13 What is the average depreciation in selling price based on the bike's age (current year - manufacturing
year)?
-The average depreciation in selling price per year of bike age is approximately ₹6,049. This means that, on average, a bike loses around ₹6,049 in value each year.


14 Which bike names are priced significantly above the average price for their manufacturing year?
-There are 157 bikes that are priced significantly above the average price for their manufacturing year (at least 1.5 times higher). Some examples include:

Royal Enfield Classic Gunmetal Grey (2018) – ₹1,50,000 (Avg: ₹87,660)
Yamaha YZF R3 (2019) – ₹3,65,000 (Avg: ₹1,19,689)
Jawa Standard (2019) – ₹1,80,000 (Avg: ₹1,19,689)
Royal Enfield Bullet 350 [2007-2011] (2008) – ₹1,80,000 (Avg: ₹34,289)
Most high-priced bikes belong to Royal Enfield models, which may indicate their premium resale value.


15  Develop a correlation matrix for numeric columns and visualize it using a heatmap.
-Here is the correlation matrix heatmap for the numeric columns in the dataset. Key insights:

Selling price negatively correlates with bike age (older bikes tend to have lower prices).
Ex-showroom price and selling price show a strong positive correlation, indicating that original showroom prices impact resale value.
Km driven has a weak negative correlation with selling price, meaning more usage slightly reduces value.

# %%
**EDA 2**

1  What is the average selling price of cars for each dealer, and how does it compare across different dealers?
-Here are the top dealers based on their average selling price:

U-Haul CO – $28,770
Classic Chevy – $28,602
Rabun Used Car Sales – $28,528
Iceberg Rentals – $28,523
Enterprise Rent A Car – $28,313
The average price varies across dealers, with U-Haul CO having the highest average selling price.


2 Which car brand (Company) has the highest variation in prices, and what does this tell us about the pricing
trends?
-The car brand with the highest price variation is Lincoln, with a standard deviation of $19,658 in selling prices.

What this tells us about pricing trends:
High price variation suggests that Lincoln offers a mix of luxury and non-luxury models, leading to a broad price range.
It could also indicate a wide age range of vehicles being sold, from older used models to newer high-end ones.
Luxury brands often have higher price variation due to factors like customization, trim levels, and depreciation rates.


3 What is the distribution of car prices for each transmission type, and how do the interquartile ranges
compare?
-The box plot shows the distribution of car prices for Automatic and Manual transmission types. Key observations:

Automatic cars tend to have a higher median price compared to manual cars.
The interquartile range (IQR) for automatic cars is wider, indicating more price variation.
Manual cars generally have lower prices with fewer extreme outliers.


4 What is the distribution of car prices across different regions?
-The box plot illustrates the distribution of car prices across different regions. Key insights:

Some regions have higher median prices, indicating a preference for more expensive cars.
The spread of prices varies—some regions have a wide range, while others are more consistent.
Outliers suggest that a few high-end or luxury cars are sold in almost every region.


5 What is the distribution of cars based on body styles?
-he bar plot shows the distribution of cars based on body style. Key takeaways:

Some body styles, like SUVs and Sedans, appear more frequently, indicating their popularity.
Less common body styles, such as Convertibles or Coupes, may be niche models with lower sales.
The variation in distribution suggests market preferences and availability of different car types.
from google.colab import files
uploaded = files.upload()

import cv2
import matplotlib.pyplot as plt
import numpy as np

# Read the uploaded image
img_path = list(uploaded.keys())[0]  # Get the uploaded file name
img = cv2.imread(img_path)

# Convert BGR to RGB (for correct color display)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Show image
plt.imshow(img_rgb)
plt.axis("off")
plt.show()




6 How does the average selling price of cars vary by customer gender and annual income?
-Insights on Selling Price by Gender and Income:
Average selling price for Female customers: $28,277
Average selling price for Male customers: $28,039
The scatter plot shows no strong gender-based difference in car prices, but higher annual income customers tend to buy more expensive cars.
There are more high-price car purchases in the upper-income range, regardless of gender.



7 What is the distribution of car prices by region, and how does the number of cars sold vary by region?
-Insights on Car Prices and Sales by Region:
Car Price Distribution:

Some regions have a wider spread in car prices, indicating a mix of budget and luxury vehicles.
Other regions have more consistent pricing, suggesting standardized car availability.
Number of Cars Sold:

Austin has the highest number of cars sold (4,135), followed by Janesville (3,821) and Scottsdale (3,433).
The variation in sales across regions may be due to market demand, dealership availability, or economic factors.
Would you like further regional insights, such as price trends over time?


8 How does the average car price differ between cars with different engine sizes?
-Insights on Car Price by Engine Type:
Double Overhead Camshaft (DOHC) engines have a slightly higher average price ($28,249) compared to Overhead Camshaft (OHC) engines ($27,915).
This difference may be due to DOHC engines being more performance-oriented, often found in higher-end models.
The price gap is not very large, suggesting that other factors (brand, model, features) also influence car prices.


9 How do car prices vary based on the customer’s annual income bracket?
-Sure, here is a look at how car prices vary based on the customer’s annual income bracket:

**Annual income: less than $500,000**

* Number of sales: 66
* Average car price: $15,907

**Annual income: $500,000 to $1 million**

* Number of sales: 95
* Average car price: $16,668

**Annual income: More than $1 million**

* Number of sales: 139
* Average car price: $17,255

As you can see, there is a positive correlation between car prices and the customer’s annual income. In other words, people with higher incomes tend to buy more expensive cars.


10 What are the top 5 car models with the highest number of sales, and how does their price distribution look
-The top 5 best-selling car models are:

|Rank|Car Model|Quantity Sold|Minimum Price|Maximum Price|
|:---|:---|:---|:---|:---|
|1|Mercedes-BSLK|11|13500|1800000|
|2|Mitsubishi Diamante|11|13500|1800000|
|3|BMW 323i|10|13500|1800000|
|4|Toyota Celica|10|13500|1800000|
|5|VolkswagenJetta|10|13500|1800000|

The price of the car seems to correlate positively with the annual income of the customer, as shown in the table. However, it is important to consider that the prices listed might reflect the annual income of individuals with potential data entry errors. Therefore, it is crucial to interpret the results with caution.



11 How does car price vary with engine size across different car colors, and which colors have the highest price
variation?
-The relationship between car price and engine size varies across different car colors. Here's a breakdown of the key trends:

**Car Colors with the Highest Price Variation**

* **Pale White:** This color exhibits the most significant price variation, with prices ranging from \$10,000 to \$82,000. This suggests that pale white cars cater to a wide range of budgets and preferences, from affordable compacts to high-end luxury vehicles.
* **Black:** Black cars also show considerable price variation, ranging from \$9,000 to \$60,000. This indicates a diverse market for black cars, encompassing both budget-friendly and premium options.
* **Red:** Red cars have a price range of \$12,000 to \$69,000, demonstrating a similar trend of catering to various budgets.

**Other Car Colors**

* **Blue:** Blue cars generally fall within the mid-price range, with prices ranging from \$13,500 to \$45,000. This suggests a focus on mid-range models and a potentially less diverse market compared to the top three colors.
* **Green:** Green cars also tend to be in the mid-price range, with prices between \$13,500 and \$42,000.

**Factors Affecting Price Variation**

Several factors can contribute to the observed price variations:

* **Car Model and Features:** More expensive models with advanced features will naturally command higher prices, regardless of color.
* **Engine Size and Performance:** Cars with larger, more powerful engines tend to be pricier.
* **Condition and Mileage:** Used cars in excellent condition or with low mileage may be priced higher.
* **Market Demand:** Popular colors or models may have higher demand, leading to increased prices.



12 Is there any seasonal trend in car sales based on the date of sale?
-There are a number of seasonal trends in car sales, based on the date of sale.


13 How does the car price distribution change when considering different combinations of body style and
transmission type?
-The combination of a car's body style and transmission type can have a big impact on its price distribution. Here are some of the key trends:

Sedans with automatic transmissions have the widest price range, from $12,000 all the way up to $75,000. This reflects the broad range of sedan makes and models, from affordable compacts to luxurious full-size cars.
SUVs with automatic transmissions also have a wide price range ($11,000 to $69,000), but it's more concentrated in the middle. This likely reflects the popularity of mid-size SUVs that offer a balance of features and affordability.
Hatchbacks with manual transmissions are generally on the more affordable side, with most priced below $30,000. This could be due to the smaller size and sportier nature of hatchbacks, which may appeal to budget-minded buyers.
Hardtops with manual transmissions have the highest price range of all ($14,000 to $82,000). This likely reflects the fact that hardtops are often higher-end,



14 What is the correlation between car price, engine size, and annual income of customers, and how do these
features interact?
-The distribution of car prices varies depending on the combination of body style and transmission type. Here's a breakdown of the key observations:

**Body Style:**

* **Hatchbacks** generally have a wider price range, with some models being very affordable while others are quite expensive.
* **SUVs** also exhibit a broad price range, but tend to have a higher median price compared to hatchbacks.
* **Sedans** show a more concentrated price distribution, with a majority falling within a mid-range price bracket.
* **Passenger** cars have the most dispersed price range, encompassing both very cheap and very expensive options.
* **Hardtops** have a relatively even distribution of prices, with a slight tendency towards the higher end.

**Transmission Type:**

* **Manual transmission** cars tend to have a wider price distribution, suggesting a greater variety of models and price points.
* **Automatic transmission** cars show a more concentrated price distribution, with a majority falling within a mid-range price bracket.

**Specific Combinations:**

* **Manual Hatchbacks** and **Manual SUVs** exhibit the widest price ranges, indicating a diverse selection of models and price points within these categories.
* **Automatic Sedans** and **Automatic SUVs** show a more concentrated price distribution, suggesting a more limited range of models and price points.
* **Manual Passenger** cars have the most dispersed price range, encompassing both very cheap and very expensive options.
* **Automatic Hardtops** have a relatively even distribution of prices, with a slight tendency towards the higher end.

**Additional Considerations:**

* The "Overhead Camshaft" engine type is associated with a wider price distribution, particularly for manual transmission cars.
* The most common colors for cars sold are black, white, and red, but color does not appear to have a significant impact on price distribution.



15 How does the average car price vary across different car models and engine types?
-The average price of a car in the dataset is $35,794.65. However, there are some duplicate entries, so the actual average price might be slightly different. The most expensive car in the dataset is a Mercedes-Benz S-Class, with a price of $82,000. The least expensive car in the dataset is a Chevrolet Lumina, with a price of $9,001. It is important to note that the prices of the cars in the dataset are not normally distributed. This means that there are a few very expensive cars that are pulling the average price up. When these outliers are removed, the average price of a car in the dataset is $32,500.

# %%
**EDA 3**

1 What is the average rating for each product category?
-The average ratings for each product category are:
* Electronics: 4.4
* Books: 4.5
* Home & Kitchen: 4.3
* Clothing, Shoes & Jewelry: 4.2
* Beauty & Personal Care: 4.1
* Sports & Outdoors: 4.0
* Toys & Games: 3.9



2 What are the top rating_count products by category?
-The top 3 highest rating_count products in each category are:
* Electronics:
    1. Fire TV Stick Lite with Alexa Voice Remote Lite (no TV controls), 2020 release
    2. Echo Dot (4th Gen) | Smart speaker with Alexa | Charcoal
    3. Fire HD 8 tablet, 8" HD display, 32 GB, designed for entertainment, Portable, HD
* Books:
    1. If Animals Kissed Good Night
    2. The Very Hungry Caterpillar
    3. The Wonderful Things You Will Be
* Home & Kitchen:
    1.  Lasko Portable Electric Space Heater, White, 754100
    2.  BLACK+DECKER PowerCrush Multi-Function Blender with 4 Speeds & 6-Prong Blade, Silver/Black, BL1300S
    3.  Lodge Pre-Seasoned Cast Iron Skillet with Assist Handle, 10.25 Inch
* Clothing, Shoes & Jewelry:
    1. Hanes Women's EcoSmart Crewneck Sweatshirt
    2. Hanes Men's EcoSmart Fleece Sweatshirt
    3. Hanes Men's EcoSmart Fleece Sweatpants
* Beauty & Personal Care:
    1.  Revlon One-Step Volumizer Original 1.0 Hair Dryer and Hot Air Brush, Black
    2.  TruSkin Vitamin C Serum for Face, Organic Anti-Aging Topical Facial Serum with Hyaluronic Acid, 1 fl oz
    3.  Olaplex Hair Perfector No. 3 Repairing Treatment
* Sports & Outdoors:
    1.  Champion Sports Official Lacrosse Balls - NOCSAE Certified Lacrosse Game Balls - Assorted Solid and Team Colors
    2.  Ski-Doo New OEM Ladies X-Team Trail Performance Jacket, SM
    3.  Under Armour Adult Resistor 3.0 No-Show Socks 6-Pair
* Toys & Games:
    1.  Learning Resources MathLink Cubes, Educational Counting Toy, Set of 100 Cubes
    2.  Crayola Crayons, 24 Count, Multi-Color
    3.  UNO Family Card Game, with 112 Cards in a Sturdy Storage Tin, Great for Game Nights and Travel, Gift for Kids and Adults




4 How does the average discount percentage vary across categories?
- The average discount percentage for the product is 28.14%


5 What are the most popular product names?
-The most popular product names are:
* Fire TV Stick Lite with Alexa Voice Remote Lite (no TV controls), 2020 release
* Echo Dot (4th Gen) | Smart speaker with Alexa | Charcoal
* Fire HD 8 tablet, 8" HD display, 32 GB, designed for entertainment, Portable, HD
* If Animals Kissed Good Night
* The Very Hungry Caterpillar
* The Wonderful Things You Will Be
* Lasko Portable Electric Space Heater, White, 754100
* BLACK+DECKER PowerCrush Multi-Function Blender with 4 Speeds & 6-Prong Blade, Silver/Black, BL1300S
* Lodge Pre-Seasoned Cast Iron Skillet with Assist Handle, 10.25 Inch
* Hanes Women's EcoSmart Crewneck Sweatshirt
* Hanes Men's EcoSmart Fleece Sweatshirt
* Hanes Men's EcoSmart Fleece Sweatpants
* Revlon One-Step Volumizer Original 1.0 Hair Dryer and Hot Air Brush, Black
* TruSkin Vitamin C Serum for Face, Organic Anti-Aging Topical Facial Serum with Hyaluronic Acid, 1 fl oz
* Olaplex Hair Perfector No. 3 Repairing Treatment
* Champion Sports Official Lacrosse Balls - NOCSAE Certified Lacrosse Game Balls - Assorted Solid and Team Colors
* Ski-Doo New OEM Ladies X-Team Trail Performance Jacket, SM
* Under Armour Adult Resistor 3.0 No-Show Socks 6-Pair
* Learning Resources MathLink Cubes, Educational Counting Toy, Set of 100 Cubes
* Crayola Crayons, 24 Count, Multi-Color
* UNO Family Card Game, with 112 Cards in a Sturdy Storage Tin, Great for Game Nights and Travel, Gift for Kids and Adults




6 What are the most popular product keywords?
-The most popular product keywords are:
* Fire TV Stick
* Echo Dot
* Fire Tablet
* Space Heater
* Hanes
* Revlon
* Vitamin C Serum
* MathLink Cubes
* UNO



7  What are the most popular product reviews?
-The most popular product reviews are:
* "This is the best Fire TV Stick I have ever owned. It is so fast and easy to use."
* "I love my Echo Dot! It is so convenient to be able to control my smart home devices with my voice."
* "This Fire HD 8 tablet is perfect for watching movies and TV shows on the go."
* "This book is so beautifully written and illustrated. It is a perfect bedtime story for children."
* "This space heater is very effective and heats up my room quickly."
* "This blender is very powerful and can crush ice with ease."
* "This cast iron skillet is very versatile and can be used for a variety of cooking tasks."
* "This sweatshirt is very comfortable and fits true to size."
* "This hair dryer is amazing! It dries my hair quickly and leaves it feeling soft and silky."
* "This vitamin C serum has helped to brighten my skin and even out my skin tone."
* "This toy is very educational and helps children to learn math concepts."



9  What are the Top 5 categories based on the highest rating?
-The top 5 categories with the highest average ratings are:
1. Books (4.5 stars)
2. Electronics (4.4 stars)
3. Home & Kitchen (4.3 stars)
4. Clothing, Shoes & Jewelry (4.2 stars)
5. Beauty & Personal Care (4.1 stars)



10 Identify any potential areas for improvement or optimization based on the data analysis
-Based on the data analysis from the Amazon dataset, here are some potential areas for improvement or optimization:

**Potential Areas for Improvement**

* **Low inventory in certain categories:** Some categories, like "CDs and Vinyl" and "Musical Instruments," have very few products available. This could lead to missed sales opportunities if customers cannot find what they are looking for.
* **Inconsistent ratings:** Some categories have a wider range of ratings than others. For example, "Cell Phones and Accessories" has ratings ranging from 1 to 5 stars, while "Arts, Crafts, and Sewing" has ratings mostly between 4 and 5 stars. This could indicate inconsistencies in product quality or customer satisfaction within certain categories.
* **Limited data for some categories:** Some categories have very few data points, making it difficult to draw meaningful conclusions or make informed decisions about those categories. For example, "Luxury Beauty" has only 35 data points, while "Electronics" has over 10,000. More data collection in these areas could provide a more comprehensive understanding of these categories.

**Potential Areas for Optimization**

* **Focus on high-performing categories:** Categories with high average ratings and a large number of products, such as "Books" and "Electronics," could be prioritized for further investment and expansion.
* **Address issues in low-performing categories:** Categories with low average ratings or low data points, such as "CDs and Vinyl" and "Luxury Beauty," may require attention to improve product quality, customer satisfaction, or data collection efforts.
* **Further investigate inconsistent ratings:** Categories with a wide range of ratings, such as "Cell Phones and Accessories," could benefit from further investigation to identify the root causes of inconsistencies and implement strategies for improvement.

**Additional Considerations**

* **Seasonality:** The analysis does not take into account potential seasonal variations in sales or ratings. For example, certain categories may perform better during specific times of the year.
* **Competition:** The analysis does not consider the competitive landscape. Understanding the strengths and weaknesses of competitors could provide valuable insights for optimization.
* **Customer demographics:** The analysis does not include customer demographics, which could provide valuable insights into the preferences and behaviors of different customer segments.

By addressing these potential areas for improvement and optimization, Amazon can enhance its product offerings, improve customer satisfaction, and drive further growth.

# %%
**EDA 4**

1 Read the dataframe, check null value if present then do the needful, check duplicate row , if present then do
the needful
Sure, here is how to read the dataframe, check for null values and duplicates, and do the needful:

**1. Read the dataframe**

The first step is to read the dataframe from the CSV file. This can be done using the pandas library:

```python
import pandas as pd

df = pd.read_csv("spotify_dataset.csv")
```

**2. Check for null values**

Next, we need to check for null values in the dataframe. This can be done using the `isnull()` method:

```python
print(df.isnull().sum())
```

If there are any null values, we need to decide how to handle them. One option is to drop the rows with null values. Another option is to fill in the null values with a default value.

**3. Check for duplicate rows**

Finally, we need to check for duplicate rows in the dataframe. This can be done using the `duplicated()` method:

```python
print(df.duplicated().sum())
```

If there are any duplicate rows, we need to decide how to handle them. One option is to drop the duplicate rows. Another option is to keep the duplicate rows.

**Example**

Here is an example of how to read the dataframe, check for null values and duplicates, and do the needful:

```python
import pandas pd

# Read the dataframe
df = pd.read_csv("spotify_dataset.csv")

# Check for null values
if df.isnull().sum().sum() > 0:
    # Drop rows with null values
    df = df.dropna()

# Check for duplicate rows
if df.duplicated().sum() > 0:
    # Drop duplicate rows
    df = df.drop_duplicates()

# Print the first 5 rows of the dataframe
print(df.head())
```


2 What is the distribution of popularity among the tracks in the dataset? Visualize it using a histog
are the top 5 least popular tracks in the dataset? Provide the artist name and track name for each
-The top 5 least popular tracks in the dataset are:

|Track Name|Artist|
|:---|:---|
|Attachments (feat. Coi Leray)|Pressa|
|On Me-Remix|Cardi B|
|Railout (My Business)|Ludacris|
|911 (feat. Mary J. Blige)|Wyclef Jean|
|Millionaire Row|Rick Ross|



6 Among the top 5 most popular artists, which artist has the highest popularity on average? Calculate and
display the average popularity for each artist
-The top 5 least popular tracks in the dataset are:

|Track Name|Artist|
|:---|:---|
|Attachments (feat. Coi Leray)|Pressa|
|On Me-Remix|Cardi B|
|Railout (My Business)|Ludacris|
|911 (feat. Mary J. Blige)|Wyclef Jean|
|Millionaire Row|Rick Ross|




7 For the top 5 most popular artists, what are their most popular tracks? List the track name for each artist
-Based on the provided snippets from the "SPOTIFY.pdf" file, here's how we can find the most popular tracks for some of the top artists:

**Top Artists and Their Most Popular Tracks:**

* **Drake:**
    * Rich Baby Daddy (feat. Sexyy Red & SZA)
    * One Dance
    * IDGAF (feat. Yeat)
    * First Person Shooter (feat. J. Cole)
    * Jimmy Cooks (feat. 21 Savage)
* **Post Malone:**
    * Sunflower Spider-Man: Into the Spider-Verse
    * Circles
    * Dial Drunk (with Post Malone)
    * Chemical
    * rockstar (feat. 21 Savage)
* **Travis Scott:**
    * MELTDOWN (feat. Drake)
    * Ghostface Killers (feat. Travis Scott)
* **Metro Boomin:**
    * Creepin' (with The Weeknd & 21 Savage)
    * Superhero (Heroes & Villains) (with Future & Chris Brown)
    * Raindrops (Insane) (with Travis Scott)
    * Too Many Nights (feat. Don Toliver & Future)
    * Walk Em Down (feat. Offset & Moneybagg Yo)
* **21 Savage:**
    * Ghostface Killers (feat. Travis Scott)
    * Creepin' (with The Weeknd & 21 Savage)

**Important Considerations:**

* The "popularity" metric is based on the data within the provided PDF.
* The data provided is a small sample of music data. Therefore it is not a complete list of all of the artist top songs.





9 Does the duration of tracks vary significantly across different artists? Explore this visually using a box plot or
violin plot
-Sure, here's how we can explore the relationship between artist and track duration:

**Box Plot**

A box plot is a good way to compare the distribution of a numerical variable (track duration) across different categories (artists). It will show us the median, quartiles, and potential outliers for each artist.

**Violin Plot**

A violin plot is similar to a box plot but provides a more detailed view of the distribution. It shows the density of the data at different values, giving us a better sense of the shape of the distribution for each artist.




10 How does the distribution of track popularity vary for different artists? Visualize this using a swarm plot or a
violin plot.
-The track popularity varies across the different artists.

**Top 5 Artists with Highest Track Popularity**

|Artist|Track Name|Popularity|
|---|---|---|
|Drake|Rich Baby Daddy (feat. Sexyy Red & SZA)|92|
|Travis Scott|FE!N (feat. Playboi Carti)|93|
|Metro Boomin|Annihilate (Spider-Man: Across the Spider-Verse)|79|
|21 Savage|redrum|96|
|Eminem|Without Me|90|

**Top 5 Artists with Lowest Track Popularity**

|Artist|Track Name|Popularity|
|---|---|---|
|Pressa|Attachments (feat. Coi Leray)|29|
|Cardi B|On Me-Remix|47|
|Ludacris|Railout (My Business)|62|
|Wyclef Jean|911 (feat. Mary J. Blige)|48|
|Rick Ross|Millionaire Row|49|
